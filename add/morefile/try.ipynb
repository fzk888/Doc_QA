# %%
from presentation import chunk

# %%
def dummy(a, b):
    pass
r = chunk('/root/autodl-tmp/py10/ragflow/test/ragflow-main/a.pptx', callback=dummy)

# %%
content = ''
for n,i in enumerate(r):
    content += i['content_with_weight']
    image_dir = image_output_dir + 'n' + '.jpg'
    content += str((image_dir))
    i['image'].save(image_dir)
    content += '***ppt换页识别符号***'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 for n,i in enumerate(r):
#       3     content += i['content_with_weight']
# ----> 4     i['image'].save(image_output_dir + 'n' + '.jpg')
#       5     content += '***ppt换页识别符号***'
#
# NameError: name 'image_output_dir' is not defined

# %%
r[0]['image'].save('a.jpg')

# %%
r[0]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x270>

# %%
r[1]['content_with_weight']
# Out:
# '目 录\n1、热点回顾\n2、概念、特点及市场\n3、元宇宙第一股——Roblox\n4、科技巨头的布局\n5、主要投资赛道\n6、总结'

# %%
for i in
